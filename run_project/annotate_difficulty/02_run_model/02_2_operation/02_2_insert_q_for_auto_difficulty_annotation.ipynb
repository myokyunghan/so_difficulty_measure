# %%
import lib.annotation.tools.Sample_Insert as si
from datetime import datetime, timedelta

# %%
def return_date_list(stday) :
    start_date = datetime(2025, 7, 28)
    end_date = datetime(2025, 12, 1)

    # 결과 날짜를 저장할 리스트
    dates = []

    # 현재 날짜를 시작 날짜로 설정
    current_date = start_date

    while current_date <= end_date:
        chk_date = (datetime(current_date.year, current_date.month, 1) + timedelta(days=stday-1))
        if chk_date <= end_date :
            dates.append([
                            (datetime(current_date.year, current_date.month, 1) + timedelta(days=stday-1)).strftime("%Y-%m-%d"), 
                            (datetime(current_date.year, current_date.month, 1) + timedelta(days=stday)).strftime("%Y-%m-%d")
                        ])
            # 다음 달로 이동
            year = current_date.year
            month = current_date.month + 1
            if month > 12:
                month = 1
                year += 1
            current_date = datetime(year, month, 1)
        else :
            break

    return dates

# %%
date = return_date_list(10)

# %%
date
# Out:
# [['2025-07-10', '2025-07-11'],
#  ['2025-08-10', '2025-08-11'],
#  ['2025-09-10', '2025-09-11'],
#  ['2025-10-10', '2025-10-11'],
#  ['2025-11-10', '2025-11-11']]

# %%
for st_dt, end_dt in date:
    num_of_date = int(date[0][0].split('-')[2])
    sample_insert = si.Sample_Insert(st_dt, end_dt, 30, 1, '1', num_of_date)
    sample_insert.insert_sample()
# Out:
# sample_insert
# sample_insert> get_id_list
# sample_insert > create connection
# sample_insert > create connection> dt_p_id_list> 2025-07-10 27
# sample_insert > create connection> dt_p_id_list> sample_num보다 작음> 2025-07-10 27 30
# Bulk insert executed successfully.
# sample_insert
# sample_insert> get_id_list
# sample_insert > create connection
# sample_insert > create connection> dt_p_id_list> 2025-08-10 10
# sample_insert > create connection> dt_p_id_list> sample_num보다 작음> 2025-08-10 10 30
# Bulk insert executed successfully.
# sample_insert
# sample_insert> get_id_list
# sample_insert > create connection
# sample_insert > create connection> dt_p_id_list> 2025-09-10 26
# sample_insert > create connection> dt_p_id_list> sample_num보다 작음> 2025-09-10 26 30
# Bulk insert executed successfully.
# sample_insert
# sample_insert> get_id_list
# sample_insert > create connection
# sample_insert > create connection> dt_p_id_list> 2025-10-10 27
# sample_insert > create connection> dt_p_id_list> sample_num보다 작음> 2025-10-10 27 30
# Bulk insert executed successfully.
# sample_insert
# sample_insert> get_id_list
# sample_insert > create connection
# sample_insert > create connection> dt_p_id_list> 2025-11-10 31
# sample_insert > create connection> first_ann_q_id> 2025-11-10 [[100069, '2025-11-10', 79815865], [100069, '2025-11-10', 79815935], [100069, '2025-11-10', 79816067], [100069, '2025-11-10', 79815407], [100069, '2025-11-10', 79815213], [100069, '2025-11-10', 79816125], [100069, '2025-11-10', 79815852], [100069, '2025-11-10', 79815438], [100069, '2025-11-10', 79815177], [100069, '2025-11-10', 79815888], [100069, '2025-11-10', 79815712], [100069, '2025-11-10', 79816102], [100069, '2025-11-10', 79815142], [100069, '2025-11-10', 79815184], [100069, '2025-11-10', 79815748], [100069, '2025-11-10', 79815515], [100069, '2025-11-10', 79815843], [100069, '2025-11-10', 79815174], [100069, '2025-11-10', 79815659], [100069, '2025-11-10', 79815375], [100069, '2025-11-10', 79815452], [100069, '2025-11-10', 79815717], [100069, '2025-11-10', 79815629], [100069, '2025-11-10', 79815408], [100069, '2025-11-10', 79815320], [100069, '2025-11-10', 79816088], [100069, '2025-11-10', 79815870], [100069, '2025-11-10', 79815983], [100069, '2025-11-10', 79815639], [100069, '2025-11-10', 79815898]]
# Bulk insert executed successfully.

# %% [markdown]
# If there is no pattern of num of date

# %%
# sample_insert = si.Sample_Insert('2022-11-29', '2022-11-30', 30, 1, '1', 1111)
# sample_insert.insert_sample()
