# %%
import setting_for_sdm.config as conf
from setting_for_sdm.date_setting import Date_Setting
from setting_for_sdm.path_setting import path_list

import lib.database.DBInterface as db_interface
import lib.utils.file_io as file_io

from datetime import datetime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       3 from setting_for_sdm.path_setting import path_list
#       5 import lib.database.DBInterface as db_interface
# ----> 6 import lib.utils.file_io as file_io
#       8 from datetime import datetime
#
# File ~/sopjt/git/so_difficulty_measure/lib/utils/file_io.py:5
#       3 import shutil
#       4 import pandas as pd
# ----> 5 from setting_for_sda.constants import CONSTANTS
#       7 def load_json(path):
#       8     """
#       9
#      10     Args:
#    (...)
#      14         a dict or a list of dict
#      15     """
#
# ModuleNotFoundError: No module named 'setting_for_sda'
