# %%
from lib.code_complexity.main import ModelRunner
from run_project.calculate_src_complexity.options import RunnerOptions

# %%
runner_opt = RunnerOptions( "real",
                            "2020to2025", # year_range (22to24, 21to23)
                            3001, # run_id 
                            'javascript',
                            "public_for_260105" # snapshot(snapshot1, snapshot2),
)

# %%
runner_opt.user_opt
# Out:
# {'run_id': 3001,
#  'year_range': '2020to2025',
#  'data_dir': '/mnt/hdd/mghan/so_difficulty_measure/data/public_for_260105/questions/javascript/2020to2025',
#  'save_dir': '/mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/run_id_3001',
#  'selected_tags': 'javascript',
#  'snapshot': 'public_for_260105'}

# %%
runner = ModelRunner(runner_opt)
runner()
# Out:
# /mnt/hdd/mghan/so_difficulty_measure/data/public_for_260105/questions/javascript/2020to2025
# 100%|██████████| 65/65 [00:10<00:00,  6.34it/s]
# [Saved] Src files are saved in /mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/run_id_3001/data/src
# Processing: 584951_76722437.js: 100%|██████████| 596927/596927 [27:27<00:00, 362.38it/s]
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/run_id_3001/data/option.json
# [src path] /mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/run_id_3001/data/csv
# [target path] /mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/run_id_3001/data
# [Saved] All complexity files are saved in /mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/run_id_3001/data/all_complexity.parquet
