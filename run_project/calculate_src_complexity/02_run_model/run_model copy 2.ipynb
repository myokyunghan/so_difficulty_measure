# %%
from setting_for_sdm.constants import CONSTANTS
from lib.code_complexity.main import ModelRunner
from run_project.calculate_src_complexity.options import RunnerOptions

# %%
gap=0

# %%
lang_list = list(CONSTANTS.src_extend.keys())

# %%
run_id_start = 2000
# for i, lang in enumerate(CONSTANTS.src_extend.keys()):
for i, lang in enumerate(lang_list):
    print('Running for language: ', lang)
    print(run_id_start - i)
    runner_opt = RunnerOptions( "real",
                                "2020to2025", # year_range (22to24, 21to23)
                                run_id_start +i, # run_id 
                                lang,
                                "public_for_260105" # snapshot(snapshot1, snapshot2),
    )
    runner = ModelRunner(runner_opt)
    runner()
    print('End Running for language: ', lang)
# Out:
# Running for language:  python
# 2000
# /mnt/hdd/mghan/so_difficulty_measure/data/public_for_260105/questions/python/2020to2025
# 100%|██████████| 65/65 [00:21<00:00,  3.03it/s]
# [Saved] Src files are saved in /mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/run_id_2000/data/src
# Processing: 365754_70290463.py: 100%|██████████| 1032155/1032155 [2:48:24<00:00, 102.15it/s]
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/run_id_2000/data/option.json
# [src path] /mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/run_id_2000/data/csv
# [target path] /mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/run_id_2000/data
# [Saved] All complexity files are saved in /mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/run_id_2000/data/all_complexity.parquet
# End Running for language:  python
# Running for language:  javascript
# 1999
# /mnt/hdd/mghan/so_difficulty_measure/data/public_for_260105/questions/javascript/2020to2025
# 100%|██████████| 65/65 [00:13<00:00,  4.90it/s]
# [Saved] Src files are saved in /mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/run_id_2001/data/src
# Processing: 584951_76722437.js: 100%|██████████| 596927/596927 [28:50<00:00, 344.89it/s]
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/run_id_2001/data/option.json
# [src path] /mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/run_id_2001/data/csv
# [target path] /mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/run_id_2001/data
# [Saved] All complexity files are saved in /mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/run_id_2001/data/all_complexity.parquet
# End Running for language:  javascript
# Running for language:  java
# 1998
# /mnt/hdd/mghan/so_difficulty_measure/data/public_for_260105/questions/java/2020to2025
# 100%|██████████| 65/65 [00:07<00:00,  8.21it/s]
# [Saved] Src files are saved in /mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/run_id_2002/data/src
# Processing: 249042_71329441.java:  49%|████▉     | 178576/362290 [08:48<08:03, 379.84it/s]
