# %% [markdown]
# ## Cyclomatic complexity 계산

# %%
from setting_for_sdm.constants import CONSTANTS
from lib.code_complexity.main import ModelRunner
from run_project.calculate_src_complexity.options import RunnerOptions

# %%
gap=0

# %%
lang_list = list(CONSTANTS.LANG_INFO.keys())

# %%
run_id_start = 20000
# for i, lang in enumerate(CONSTANTS.src_extend.keys()):
for i, lang in enumerate(lang_list):
    print('Running for language: ', lang)
    print(run_id_start + i)
    runner_opt = RunnerOptions( "real",
                                "2020to2025", # year_range (22to24, 21to23)
                                run_id_start +i, # run_id 
                                lang,
                                "public_for_260105", # snapshot(snapshot1, snapshot2)
                                "cyclomatic_complexity"
    )
    runner = ModelRunner(runner_opt)
    runner()
    print('End Running for language: ', lang)
# Out:
# Running for language:  python
# 20000
# snapshot public_for_260105
# /mnt/hdd/mghan/so_difficulty_measure/data/public_for_260105/questions/python/2020to2025
# 100%|██████████| 65/65 [00:16<00:00,  3.84it/s]
# [Saved] Src files are saved in /mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/cyclomatic_complexity/run_id_20000/data/src
# Processing: 365754_70290463.py: 100%|██████████| 1032155/1032155 [42:37<00:00, 403.53it/s]
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/cyclomatic_complexity/run_id_20000/data/option.json
# [src path] /mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/cyclomatic_complexity/run_id_20000/data/jsonl
# [target path] /mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/cyclomatic_complexity/run_id_20000/data
# [Saved] /mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/cyclomatic_complexity/run_id_20000/data/all_complexity.jsonl
# End Running for language:  python
# Running for language:  javascript
# 20001
# snapshot public_for_260105
# /mnt/hdd/mghan/so_difficulty_measure/data/public_for_260105/questions/javascript/2020to2025
# 100%|██████████| 65/65 [00:10<00:00,  6.19it/s]
# [Saved] Src files are saved in /mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/cyclomatic_complexity/run_id_20001/data/src
# Processing: 406914_71279734.js:  89%|████████▊ | 528597/596927 [21:46<03:08, 362.83it/s]
