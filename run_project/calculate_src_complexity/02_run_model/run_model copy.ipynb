# %%
from lib.code_complexity.main import ModelRunner
from run_project.calculate_src_complexity.options import RunnerOptions

# %%
runner_opt = RunnerOptions( "real",
                            "2020to2025", # year_range (22to24, 21to23)
                            5, # run_id 
                            'python',
                            "public_for_260105" # snapshot(snapshot1, snapshot2),
)

# %%
runner_opt.user_opt
# Out:
# {'run_id': 1000,
#  'year_range': '2020to2025',
#  'data_dir': '/mnt/hdd/mghan/so_difficulty_measure/data/public_for_260105/questions/python/2020to2025',
#  'save_dir': '/mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/run_id_1000',
#  'selected_tags': 'python',
#  'snapshot': 'public_for_260105'}

# %%
runner = ModelRunner(runner_opt)
runner()
# Out:
# /mnt/hdd/mghan/so_difficulty_measure/data/public_for_260105/questions/python/2020to2025
# 100%|██████████| 65/65 [00:13<00:00,  4.75it/s]
# [Saved] Src files are saved in /mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/run_id_1000/data/src
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 runner = ModelRunner(runner_opt)
# ----> 2 runner()
#
# File ~/sopjt/git/so_difficulty_measure/lib/code_complexity/main.py:34, in ModelRunner.__call__(self)
#      33 def __call__(self):
# ---> 34     self.run()
#
# File ~/sopjt/git/so_difficulty_measure/lib/code_complexity/main.py:47, in ModelRunner.run(self)
#      44 src_list = self.extract_src_from_q(df[['id', 'body']].to_dict(orient='records'))
#      45 self.save_file(src_list)
# ---> 47 self.calculate_complexity()
#      48 self.save_option()
#      49 save_many_to_one(self.save_dir_for_csv, self.save_dir_for_one, "all_complexity")
#
# File ~/sopjt/git/so_difficulty_measure/lib/code_complexity/main.py:55, in ModelRunner.calculate_complexity(self)
#      53 list_ = os.listdir(self.save_dir_for_src)
#      54 for i in list_:
# ---> 55     call_cognitive_complexity(i,self.lang, self.save_dir_for_src, self.save_dir_for_csv)
#      57 print(f'[Saved] complexity files are saved in {self.save_dir_for_csv}')
#
# File ~/sopjt/git/so_difficulty_measure/lib/code_complexity/cognitive_complexity.py:19, in call_cognitive_complexity(file, lang, save_dir_for_src, save_dir_for_csv)
#      16 new_nm = os.path.splitext(name)[0]
#      17 new_file = f"{new_nm}.csv"
# ---> 19 results = CALC_FUNC[lang](file_path)
#      20 total_complexity = sum(r['complexity'] for r in results)
#      21 pd.DataFrame([[new_file, new_file, total_complexity]], columns=['Path', 'File Name', 'Cognitive Complexity'])\
#      22     .to_csv(f'{save_dir_for_csv}/{new_file}')
#
# File ~/sopjt/git/so_difficulty_measure/lib/code_complexity/cognitive_complexity_for_python.py:559, in calculate_file(filepath)
#     557 def calculate_file(filepath: str):
#     558     with open(filepath, "r", encoding="utf-8") as f:
# --> 559         source = f.read()
#     560     calc = CognitiveComplexityCalculator(source)
#     561     return calc.calculate()
#
# File /usr/lib/python3.10/codecs.py:319, in BufferedIncrementalDecoder.decode(self, input, final)
#     314 def _buffer_decode(self, input, errors, final):
#     315     # Overwrite this method in subclasses: It must decode input
#     316     # and return an (output, length consumed) tuple
#     317     raise NotImplementedError
# --> 319 def decode(self, input, final=False):
#     320     # decode input (taking the buffer into account)
#     321     data = self.buffer + input
#     322     (result, consumed) = self._buffer_decode(data, self.errors, final)
#
# KeyboardInterrupt:
