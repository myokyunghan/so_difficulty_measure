# %%
from lib.code_complexity.main import ModelRunner
from run_project.calculate_src_complexity.options import RunnerOptions

# %%
runner_opt = RunnerOptions( "real",
                            "2020to2025", # year_range (22to24, 21to23)
                            10, # run_id 
                            'prolog', # lang
                            "public_for_260105" # snapshot(snapshot1, snapshot2),
)

# %%
runner_opt.user_opt
# Out:
# {'run_id': 10,
#  'year_range': '2020to2025',
#  'data_dir': '/mnt/hdd/mghan/so_difficulty_measure/data/public_for_260105/questions/prolog/2020to2025',
#  'save_dir': '/mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/run_id_10',
#  'selected_tags': 'prolog',
#  'snapshot': 'public_for_260105'}

# %%
runner = ModelRunner(runner_opt)
runner()
# Out:
# /mnt/hdd/mghan/so_difficulty_measure/data/public_for_260105/questions/prolog/2020to2025
# 100%|██████████| 65/65 [00:00<00:00, 1288.23it/s]
# [Saved] Src files are saved in /mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/run_id_10/data/src
# Processing: 2756_67972830.pl: 100%|██████████| 3290/3290 [00:09<00:00, 349.15it/s]
# [Saving data...] Saved to runner option to /mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/run_id_10/data/option.json
# [src path] /mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/run_id_10/data/csv
# [target path] /mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/run_id_10/data
# [Saved] All complexity files are saved in /mnt/hdd/mghan/so_difficulty_measure/result/code_complexity/run_id_10/data/all_complexity.parquet
